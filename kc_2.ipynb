# %%
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('assets/national_assessment_of_educational_progress_2022.csv')
df.head()
# Out:
#    SCHOOL YEAR  COUNTY NUMBER  COUNTY NAME  DISTRICT NUMBER DISTRICT NAME  \
# 0     20212022            NaN          NaN              999         State
# 1     20212022            NaN          NaN              999         State
# 2     20212022            NaN          NaN              999         State
# 3     20212022            NaN          NaN              999         State
# 4     20212022            NaN          NaN              999         State
#
#    SCHOOL NUMBER        SCHOOL NAME  SCHOOL CODE  STATE SCHOOL ID  NCES ID  \
# 0            NaN  ---State Total---          999              NaN      NaN
# 1            NaN  ---State Total---          999              NaN      NaN
# 2            NaN  ---State Total---          999              NaN      NaN
# 3            NaN  ---State Total---          999              NaN      NaN
# 4            NaN  ---State Total---          999              NaN      NaN
#
#    ...  SCHOOL TYPE  SUBJECT  GRADE   DEMOGRAPHIC     LEVEL  \
# ...

# %%
df_sorted = df.sort_values('PERCENT PROFICIENT')
df_sorted.head()
#print(df_sorted).head()
# Out:
#     SCHOOL YEAR  COUNTY NUMBER  COUNTY NAME  DISTRICT NUMBER DISTRICT NAME  \
# 81     20212022            NaN          NaN              999         State
# 27     20212022            NaN          NaN              999         State
# 31     20212022            NaN          NaN              999         State
# 80     20212022            NaN          NaN              999         State
# 9      20212022            NaN          NaN              999         State
#
#     SCHOOL NUMBER        SCHOOL NAME  SCHOOL CODE  STATE SCHOOL ID  NCES ID  \
# 81            NaN  ---State Total---          999              NaN      NaN
# 27            NaN  ---State Total---          999              NaN      NaN
# 31            NaN  ---State Total---          999              NaN      NaN
# 80            NaN  ---State Total---          999              NaN      NaN
# 9             NaN  ---State Total---          999              NaN      NaN
#
# ...

# %%
sns.scatterplot(x=df['DEMOGRAPHIC'],
                y=df['PERCENT PROFICIENT'])
# Out:
# <AxesSubplot:xlabel='DEMOGRAPHIC', ylabel='PERCENT PROFICIENT'>
